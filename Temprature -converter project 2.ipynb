# %%
# week 2 project
## Temperature  converter
# **convert Celcius  to Fahrenheite and Fahrenhite  to Celsius

# %%
# Temperature Converter: Celsius to Fahrenheit

def celsius_to_fahrenheit(celsius):
    """
    Convert Celsius to Fahrenheit using the formula:
    F = (C × 9/5) + 32
    """
    return (celsius * 9/5) + 32

def main():
    try:
        # Get user input
        celsius_input = input("Enter temperature in Celsius: ").strip()
        
        # Validate and convert to float
        celsius = float(celsius_input)
        
        # Perform conversion
        fahrenheit = celsius_to_fahrenheit(celsius)
        
        # Display result
        print(f"{celsius:.2f}°C is equal to {fahrenheit:.2f}F")
    
    except ValueError:
        print(f"Error:please enter a valid number!")

        if _name_ =="_main_":()

# %%
# Fahrenheit to celsisus
def fahrenheit_to_celsius(fahrenheit):
    celsius = (fahrenheit - 32)*5/9
    return celsius
    
try:
    fahrenheit_input = float(input("Enter temperature in Fahrenheit:"))
    celsius_result= fahrenheit_to_celsius(fahrenheit_input)
    print(f"{fahrenheit_input:1f}fahrenheit is equal to{celsius_result:1f}celsius")
except ValueError:
    print("Error:please enter a valid number!")

    if name =="_main_":
        pass
# Out:
# Enter temperature in Fahrenheit: 32
# 32.000000fahrenheit is equal to0.000000celsius
