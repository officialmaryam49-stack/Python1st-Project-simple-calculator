# %%
print("hello world")
# Out:
# hello world

# %%
# simple calculator my first project

# %%
# %%markdown
# #**Simple Calculator
# Out:
# #**Simple Calculator

# %%
#this notebook takes two number and performes Addition and subtirction Multiplycation,And division

# %%
print("==== simple calculator =====")
# take two numbers from the user
number1 = float(input("Enter first number:"))
number2 = float(input("Enter second number (not zero):"))

# perform calculation 
addition = number1 + number2
subtraction = number1 - number2
multiplication = number1*number2
division = number1/number2

#display the result
print("\n==== results =====")
print("Addition:", addition)
print("Subtraction:",subtraction)
print("Multiplication:",multiplication)
print("Division:",division)
# Out:
# ==== simple calculator =====
# Enter first number: 34
# Enter second number (not zero): 12
# ==== results =====
# Addition: 46.0
# Subtraction: 22.0
# Multiplication: 408.0
# Division: 2.8333333333333335
